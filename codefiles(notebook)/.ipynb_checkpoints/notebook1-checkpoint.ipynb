# %%
import pandas as pd 
import os

# Your original data_path without a slash
data_path = '../data'
file_name_1 = 'Flight Level Data.csv'
file_name_2 = 'PNR+Flight+Level+Data.csv'
file_name_3 = 'PNR Remark Level Data.csv'
file_name_4 = 'Bag+Level+Data.csv'
file_name_5 = 'Airports Data.csv'

# Safely join the path components
full_path_1 = os.path.join(data_path, file_name_1)
full_path_2 = os.path.join(data_path, file_name_2)
full_path_3 = os.path.join(data_path, file_name_3)
full_path_4 = os.path.join(data_path, file_name_4)
full_path_5 = os.path.join(data_path, file_name_5)
# Read the CSV
flight_df = pd.read_csv(full_path_1)
pnr_flight_df= pd.read_csv(full_path_2)
pnr_remark_df= pd.read_csv(full_path_3)
bag_df= pd.read_csv(full_path_4)
airport_df= pd.read_csv(full_path_5)
print("File loaded successfully!")
# Out:
# File loaded successfully!

# %%
flight_df.info()
pnr_flight_df.info()
pnr_remark_df.info()
bag_df.info()
airport_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8099 entries, 0 to 8098
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   company_id                          8099 non-null   object
#  1   flight_number                       8099 non-null   int64
#  2   scheduled_departure_date_local      8099 non-null   object
#  3   scheduled_departure_station_code    8099 non-null   object
#  4   scheduled_arrival_station_code      8099 non-null   object
#  5   scheduled_departure_datetime_local  8099 non-null   object
#  6   scheduled_arrival_datetime_local    8099 non-null   object
#  7   actual_departure_datetime_local     8099 non-null   object
#  8   actual_arrival_datetime_local       8099 non-null   object
#  9   total_seats                         8099 non-null   int64
#  10  fleet_type                          8099 non-null   object
#  11  carrier                             8099 non-null   object
#  12  scheduled_ground_time_minutes       8099 non-null   int64
#  13  actual_ground_time_minutes          8099 non-null   int64
#  14  minimum_turn_minutes                8099 non-null   int64
# dtypes: int64(5), object(10)
# memory usage: 949.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 687878 entries, 0 to 687877
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   company_id                        687878 non-null  object
#  1   flight_number                     687878 non-null  int64
#  2   scheduled_departure_date_local    687878 non-null  object
#  3   scheduled_departure_station_code  687878 non-null  object
#  4   scheduled_arrival_station_code    687878 non-null  object
#  5   record_locator                    687878 non-null  object
#  6   pnr_creation_date                 687878 non-null  object
#  7   total_pax                         687878 non-null  int64
#  8   is_child                          687878 non-null  object
#  9   basic_economy_ind                 687878 non-null  int64
#  10  is_stroller_user                  687878 non-null  object
#  11  lap_child_count                   687878 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 63.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51698 entries, 0 to 51697
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   record_locator           51698 non-null  object
#  1   pnr_creation_date        51698 non-null  object
#  2   flight_number            51698 non-null  int64
#  3   special_service_request  51698 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 687245 entries, 0 to 687244
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   company_id                        687245 non-null  object
#  1   flight_number                     687245 non-null  int64
#  2   scheduled_departure_date_local    687245 non-null  object
#  3   scheduled_departure_station_code  687245 non-null  object
#  4   scheduled_arrival_station_code    687245 non-null  object
#  5   bag_tag_unique_number             687245 non-null  object
#  6   bag_tag_issue_date                687245 non-null  object
#  7   bag_type                          687245 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 41.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5612 entries, 0 to 5611
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   airport_iata_code  5612 non-null   object
#  1   iso_country_code   5597 non-null   object
# dtypes: object(2)
# memory usage: 87.8+ KB

# %%
airport_df.isnull().sum()
# Out:
# airport_iata_code     0
# iso_country_code     15
# dtype: int64

# %%
# Assuming 'airports_df' is your loaded DataFrame from the Airports Data.csv file

# Filter the DataFrame to find rows where 'iso_country_code' is missing (is null)
missing_country_codes = airport_df[airport_df['iso_country_code'].isnull()]

# Print the resulting DataFrame
print("Airports with missing ISO country codes:")
print(missing_country_codes)
# Out:
# Airports with missing ISO country codes:
#      airport_iata_code iso_country_code
# 321                OND              NaN
# 322                ERS              NaN
# 323                WDH              NaN
# 2628               ADI              NaN
# 2629               GOG              NaN
# 2630               GFY              NaN
# 2631               MPA              NaN
# 2632               KMP              NaN
# 2633               LUD              NaN
# 2634               OKU              NaN
# 2635               OMD              NaN
# 2636               NDU              NaN
# 2637               RHN              NaN
# 2638               SWP              NaN
# 2639               WVB              NaN

# %%
# --- 2. Data Cleaning and Type Conversion ---

print("Cleaning data and converting types...")

# Convert date/time columns
date_cols_flight = [
    'scheduled_departure_date_local', 'scheduled_departure_datetime_local',
    'scheduled_arrival_datetime_local', 'actual_departure_datetime_local',
    'actual_arrival_datetime_local'
]
for col in date_cols_flight:
    flight_df[col] = pd.to_datetime(flight_df[col])

print("✅ Flight date/time conversion successful!")
# Out:
# Cleaning data and converting types...
# ✅ Flight date/time conversion successful!

# %%
pnr_flight_df['scheduled_departure_date_local'] = pd.to_datetime(pnr_flight_df['scheduled_departure_date_local'])
pnr_flight_df['pnr_creation_date'] = pd.to_datetime(pnr_flight_df['pnr_creation_date'])
pnr_remark_df['pnr_creation_date'] = pd.to_datetime(pnr_remark_df['pnr_creation_date'])
bag_df['scheduled_departure_date_local'] = pd.to_datetime(bag_df['scheduled_departure_date_local'])
bag_df['bag_tag_issue_date'] = pd.to_datetime(bag_df['bag_tag_issue_date'])
print("Date/time conversion complete.")
# Out:
# Date/time conversion complete.

# %%
# Convert boolean-like columns to numeric (1/0)
pnr_flight_df['is_child_numeric'] = pnr_flight_df['is_child'].map({'Y': 1, 'N': 0})
pnr_flight_df['is_stroller_user_numeric'] = pnr_flight_df['is_stroller_user'].map({'Y': 1, 'N': 0})

# Handle missing values important 

# Fill missing iso_country_code in airport_df with the mode
mode_country = airport_df['iso_country_code'].mode()[0]
airport_df['iso_country_code'] = airport_df['iso_country_code'].fillna(mode_country)

print("Data cleaning complete.")
print("-" * 50)
# Out:
# Data cleaning complete.
# --------------------------------------------------

# %%
flight_key = [
    'flight_number',
    'scheduled_departure_datetime_local', # This includes the time
    'scheduled_departure_station_code'
]

# Now, check for duplicates based on this key
duplicate_rows = flight_df.duplicated(subset=flight_key).sum()

# Print the result
print(f"Number of duplicate flights found using the key: {duplicate_rows}")

if duplicate_rows == 0:
    print("✅ The key is unique. Your logic is solid.")
else:
    print("❌ Warning: Duplicate rows found. This indicates a potential data quality issue.")

# Use keep=False to show ALL rows that are part of a duplicate set
duplicate_flights = flight_df[flight_df.duplicated(subset=flight_key, keep=False)]

# Sort the results to see the duplicates grouped together
print(duplicate_flights.sort_values(by=flight_key))
# Out:
# Number of duplicate flights found using the key: 23
# ❌ Warning: Duplicate rows found. This indicates a potential data quality issue.
#      company_id  flight_number scheduled_departure_date_local  \
# 1435         UA            611                     2025-08-10
# 2186         UA            611                     2025-08-10
# 6910         UA            611                     2025-08-10
# 7063         UA            611                     2025-08-10
# 5320         UA            881                     2025-08-09
# 6363         UA            881                     2025-08-09
# 558          UA            881                     2025-08-09
# 4297         UA            881                     2025-08-09
# 5622         UA            909                     2025-08-09
# 7617         UA            909                     2025-08-09
# 1640         UA           1270                     2025-08-10
# 7673         UA           1270                     2025-08-10
# 3844         UA           1270                     2025-08-10
# 4273         UA           1270                     2025-08-10
# 472          UA           1775                     2025-08-04
# 7736         UA           1775                     2025-08-04
# 1659         UA           1775                     2025-08-04
# 7861         UA           1775                     2025-08-04
# 1210         UA           1857                     2025-08-07
# 3657         UA           1857                     2025-08-07
# 3741         UA           1857                     2025-08-07
# 4828         UA           1857                     2025-08-07
# 7289         UA           2144                     2025-08-12
# 7633         UA           2144                     2025-08-12
# 5420         UA           2144                     2025-08-12
# 6627         UA           2144                     2025-08-12
# 4445         UA           2635                     2025-08-01
# 5403         UA           2635                     2025-08-01
# 767          UA           2635                     2025-08-01
# 3480         UA           2635                     2025-08-01
# 125          G7           4482                     2025-08-11
# 2955         G7           4482                     2025-08-11
# 2662         G7           4482                     2025-08-11
# 3149         G7           4482                     2025-08-11
# 1834         G7           4597                     2025-08-11
# 4413         G7           4597                     2025-08-11
# 5431         G7           4597                     2025-08-11
# 5555         G7           4597                     2025-08-11
# 6064         OO           5021                     2025-08-04
# 6681         OO           5021                     2025-08-04
# 7669         OO           5251                     2025-08-10
# 7839         OO           5251                     2025-08-10
# 303          OO           5565                     2025-08-13
# 7126         OO           5565                     2025-08-13
# 6811         OO           5565                     2025-08-13
# 8003         OO           5565                     2025-08-13
#
#      scheduled_departure_station_code scheduled_arrival_station_code  \
# 1435                              ORD                            SFO
# 2186                              ORD                            SFO
# 6910                              ORD                            SFO
# 7063                              ORD                            SFO
# 5320                              ORD                            HND
# 6363                              ORD                            HND
# 558                               ORD                            HND
# 4297                              ORD                            HND
# 5622                              ORD                            AMS
# 7617                              ORD                            AMS
# 1640                              ORD                            PUJ
# 7673                              ORD                            PUJ
# 3844                              ORD                            PUJ
# 4273                              ORD                            PUJ
# 472                               ORD                            FLL
# 7736                              ORD                            FLL
# 1659                              ORD                            FLL
# 7861                              ORD                            FLL
# 1210                              ORD                            MIA
# 3657                              ORD                            MIA
# 3741                              ORD                            MIA
# 4828                              ORD                            MIA
# 7289                              ORD                            YYZ
# 7633                              ORD                            YYZ
# 5420                              ORD                            YYZ
# 6627                              ORD                            YYZ
# 4445                              ORD                            CLT
# 5403                              ORD                            CLT
# 767                               ORD                            CLT
# 3480                              ORD                            CLT
# 125                               ORD                            TUL
# 2955                              ORD                            TUL
# 2662                              ORD                            TUL
# 3149                              ORD                            TUL
# 1834                              ORD                            ROA
# 4413                              ORD                            ROA
# 5431                              ORD                            ROA
# 5555                              ORD                            ROA
# 6064                              ORD                            SUX
# 6681                              ORD                            SUX
# 7669                              ORD                            ASE
# 7839                              ORD                            ASE
# 303                               ORD                            CHO
# 7126                              ORD                            CHO
# 6811                              ORD                            CHO
# 8003                              ORD                            CHO
#
#      scheduled_departure_datetime_local scheduled_arrival_datetime_local  \
# 1435          2025-08-10 07:00:00+00:00        2025-08-10 10:40:00+00:00
# 2186          2025-08-10 07:00:00+00:00        2025-08-10 10:40:00+00:00
# 6910          2025-08-10 10:41:00+00:00        2025-08-10 09:42:00+00:00
# 7063          2025-08-10 10:41:00+00:00        2025-08-10 09:42:00+00:00
# 5320          2025-08-09 12:50:00+00:00        2025-08-09 14:50:00+00:00
# 6363          2025-08-09 12:50:00+00:00        2025-08-09 14:50:00+00:00
# 558           2025-08-09 16:54:00+00:00        2025-08-10 15:55:00+00:00
# 4297          2025-08-09 16:54:00+00:00        2025-08-10 15:55:00+00:00
# 5622          2025-08-09 18:15:00+00:00        2025-08-09 23:57:00+00:00
# 7617          2025-08-09 18:15:00+00:00        2025-08-09 23:57:00+00:00
# 1640          2025-08-10 09:23:00+00:00        2025-08-10 14:09:00+00:00
# 7673          2025-08-10 09:23:00+00:00        2025-08-10 14:09:00+00:00
# 3844          2025-08-10 16:25:00+00:00        2025-08-10 15:05:00+00:00
# 4273          2025-08-10 16:25:00+00:00        2025-08-10 15:05:00+00:00
# 472           2025-08-04 10:45:00+00:00        2025-08-04 17:01:00+00:00
# 7736          2025-08-04 10:45:00+00:00        2025-08-04 17:01:00+00:00
# 1659          2025-08-04 17:31:00+00:00        2025-08-04 15:03:00+00:00
# 7861          2025-08-04 17:31:00+00:00        2025-08-04 15:03:00+00:00
# 1210          2025-08-07 10:54:00+00:00        2025-08-07 15:44:00+00:00
# 3657          2025-08-07 10:54:00+00:00        2025-08-07 15:44:00+00:00
# 3741          2025-08-07 20:11:00+00:00        2025-08-07 15:14:00+00:00
# 4828          2025-08-07 20:11:00+00:00        2025-08-07 15:14:00+00:00
# 7289          2025-08-12 13:01:00+00:00        2025-08-12 18:33:00+00:00
# 7633          2025-08-12 13:01:00+00:00        2025-08-12 18:33:00+00:00
# 5420          2025-08-12 18:34:00+00:00        2025-08-12 15:46:00+00:00
# 6627          2025-08-12 18:34:00+00:00        2025-08-12 15:46:00+00:00
# 4445          2025-08-01 14:08:00+00:00        2025-08-01 19:12:00+00:00
# 5403          2025-08-01 14:08:00+00:00        2025-08-01 19:12:00+00:00
# 767           2025-08-01 19:13:00+00:00        2025-08-01 17:18:00+00:00
# 3480          2025-08-01 19:13:00+00:00        2025-08-01 17:18:00+00:00
# 125           2025-08-11 15:35:00+00:00        2025-08-11 18:22:00+00:00
# 2955          2025-08-11 15:35:00+00:00        2025-08-11 18:22:00+00:00
# 2662          2025-08-11 19:40:00+00:00        2025-08-11 17:35:00+00:00
# 3149          2025-08-11 19:40:00+00:00        2025-08-11 17:35:00+00:00
# 1834          2025-08-11 07:15:00+00:00        2025-08-11 10:44:00+00:00
# 4413          2025-08-11 07:15:00+00:00        2025-08-11 10:44:00+00:00
# 5431          2025-08-11 11:26:00+00:00        2025-08-11 10:14:00+00:00
# 5555          2025-08-11 11:26:00+00:00        2025-08-11 10:14:00+00:00
# 6064          2025-08-04 20:50:00+00:00        2025-08-04 22:40:00+00:00
# 6681          2025-08-04 20:50:00+00:00        2025-08-04 22:40:00+00:00
# 7669          2025-08-10 19:35:00+00:00        2025-08-11 03:14:00+00:00
# 7839          2025-08-10 19:35:00+00:00        2025-08-11 03:14:00+00:00
# 303           2025-08-13 14:04:00+00:00        2025-08-13 17:43:00+00:00
# 7126          2025-08-13 14:04:00+00:00        2025-08-13 17:43:00+00:00
# 6811          2025-08-13 18:21:00+00:00        2025-08-13 17:10:00+00:00
# 8003          2025-08-13 18:21:00+00:00        2025-08-13 17:10:00+00:00
#
#      actual_departure_datetime_local actual_arrival_datetime_local  \
# 1435       2025-08-10 07:06:00+00:00     2025-08-10 10:40:00+00:00
# 2186       2025-08-10 07:06:00+00:00     2025-08-10 10:40:00+00:00
# 6910       2025-08-10 10:41:00+00:00     2025-08-10 12:03:00+00:00
# 7063       2025-08-10 10:41:00+00:00     2025-08-10 12:03:00+00:00
# 5320       2025-08-09 12:50:00+00:00     2025-08-09 14:50:00+00:00
# 6363       2025-08-09 12:50:00+00:00     2025-08-09 14:50:00+00:00
# 558        2025-08-09 16:54:00+00:00     2025-08-10 20:09:00+00:00
# 4297       2025-08-09 16:54:00+00:00     2025-08-10 20:09:00+00:00
# 5622       2025-08-09 18:58:00+00:00     2025-08-09 23:57:00+00:00
# 7617       2025-08-09 18:58:00+00:00     2025-08-09 23:57:00+00:00
# 1640       2025-08-10 09:29:00+00:00     2025-08-10 14:09:00+00:00
# 7673       2025-08-10 09:29:00+00:00     2025-08-10 14:09:00+00:00
# 3844       2025-08-10 16:25:00+00:00     2025-08-10 20:19:00+00:00
# 4273       2025-08-10 16:25:00+00:00     2025-08-10 20:19:00+00:00
# 472        2025-08-04 10:44:00+00:00     2025-08-04 17:01:00+00:00
# 7736       2025-08-04 10:44:00+00:00     2025-08-04 17:01:00+00:00
# 1659       2025-08-04 17:31:00+00:00     2025-08-04 18:16:00+00:00
# 7861       2025-08-04 17:31:00+00:00     2025-08-04 18:16:00+00:00
# 1210       2025-08-07 10:53:00+00:00     2025-08-07 15:44:00+00:00
# 3657       2025-08-07 10:53:00+00:00     2025-08-07 15:44:00+00:00
# 3741       2025-08-07 20:11:00+00:00     2025-08-07 21:11:00+00:00
# 4828       2025-08-07 20:11:00+00:00     2025-08-07 21:11:00+00:00
# 7289       2025-08-12 13:23:00+00:00     2025-08-12 18:33:00+00:00
# 7633       2025-08-12 13:23:00+00:00     2025-08-12 18:33:00+00:00
# 5420       2025-08-12 18:34:00+00:00     2025-08-12 19:15:00+00:00
# 6627       2025-08-12 18:34:00+00:00     2025-08-12 19:15:00+00:00
# 4445       2025-08-01 14:14:00+00:00     2025-08-01 19:12:00+00:00
# 5403       2025-08-01 14:14:00+00:00     2025-08-01 19:12:00+00:00
# 767        2025-08-01 19:13:00+00:00     2025-08-01 20:25:00+00:00
# 3480       2025-08-01 19:13:00+00:00     2025-08-01 20:25:00+00:00
# 125        2025-08-11 15:47:00+00:00     2025-08-11 18:22:00+00:00
# 2955       2025-08-11 15:47:00+00:00     2025-08-11 18:22:00+00:00
# 2662       2025-08-11 19:40:00+00:00     2025-08-11 21:20:00+00:00
# 3149       2025-08-11 19:40:00+00:00     2025-08-11 21:20:00+00:00
# 1834       2025-08-11 07:07:00+00:00     2025-08-11 10:44:00+00:00
# 4413       2025-08-11 07:07:00+00:00     2025-08-11 10:44:00+00:00
# 5431       2025-08-11 11:26:00+00:00     2025-08-11 12:20:00+00:00
# 5555       2025-08-11 11:26:00+00:00     2025-08-11 12:20:00+00:00
# 6064       2025-08-04 20:44:00+00:00     2025-08-04 22:40:00+00:00
# 6681       2025-08-04 20:44:00+00:00     2025-08-04 22:40:00+00:00
# 7669       2025-08-11 01:28:00+00:00     2025-08-11 03:14:00+00:00
# 7839       2025-08-11 01:28:00+00:00     2025-08-11 03:14:00+00:00
# 303        2025-08-13 14:15:00+00:00     2025-08-13 17:43:00+00:00
# 7126       2025-08-13 14:15:00+00:00     2025-08-13 17:43:00+00:00
# 6811       2025-08-13 18:21:00+00:00     2025-08-13 19:08:00+00:00
# 8003       2025-08-13 18:21:00+00:00     2025-08-13 19:08:00+00:00
#
#       total_seats fleet_type   carrier  scheduled_ground_time_minutes  \
# 1435          234   B757-300  Mainline                            655
# 2186          234   B757-300  Mainline                             20
# 6910          234   B757-300  Mainline                             20
# 7063          234   B757-300  Mainline                            655
# 5320          318    B787-10  Mainline                            365
# 6363          318    B787-10  Mainline                             20
# 558           318    B787-10  Mainline                             20
# 4297          318    B787-10  Mainline                            365
# 5622          243     B787-8  Mainline                            280
# 7617          243     B787-8  Mainline                            366
# 1640          179   B737-900  Mainline                             97
# 7673          179   B737-900  Mainline                            -22
# 3844          179   B737-900  Mainline                             97
# 4273          179   B737-900  Mainline                            -22
# 472           179  B737-MAX9  Mainline                            743
# 7736          179  B737-MAX9  Mainline                             20
# 1659          179  B737-MAX9  Mainline                             20
# 7861          179  B737-MAX9  Mainline                            743
# 1210          166   B737-800  Mainline                             20
# 3657          166   B737-800  Mainline                             75
# 3741          166   B737-800  Mainline                             20
# 4828          166   B737-800  Mainline                             75
# 7289          126   A319-100  Mainline                             76
# 7633          126   A319-100  Mainline                             20
# 5420          126   A319-100  Mainline                             20
# 6627          126   A319-100  Mainline                             76
# 4445          126   B737-700  Mainline                             20
# 5403          126   B737-700  Mainline                             71
# 767           126   B737-700  Mainline                             20
# 3480          126   B737-700  Mainline                             71
# 125            50    CRJ-550   Express                            -36
# 2955           50    CRJ-550   Express                             67
# 2662           50    CRJ-550   Express                             67
# 3149           50    CRJ-550   Express                            -36
# 1834           50    CRJ-550   Express                             38
# 4413           50    CRJ-550   Express                           -120
# 5431           50    CRJ-550   Express                             38
# 5555           50    CRJ-550   Express                           -120
# 6064           50    CRJ-200   Express                             20
# 6681           50    CRJ-200   Express                            120
# 7669           70    ERJ-175   Express                           -189
# 7839           70    ERJ-175   Express                             68
# 303            50    CRJ-550   Express                             20
# 7126           50    CRJ-550   Express                             41
# 6811           50    CRJ-550   Express                             20
# 8003           50    CRJ-550   Express                             41
#
#       actual_ground_time_minutes  minimum_turn_minutes
# 1435                         496                    66
# 2186                           1                    66
# 6910                           1                    66
# 7063                         496                    66
# 5320                         309                   155
# 6363                         124                   100
# 558                          124                   100
# 4297                         309                   155
# 5622                         350                    95
# 7617                         365                   155
# 1640                         122                    70
# 7673                         113                    70
# 3844                         122                    70
# 4273                         113                    70
# 472                          768                    56
# 7736                          30                    56
# 1659                          30                    56
# 7861                         768                    56
# 1210                         267                    51
# 3657                         101                    51
# 3741                         267                    51
# 4828                         101                    51
# 7289                         108                    52
# 7633                           1                    52
# 5420                           1                    52
# 6627                         108                    52
# 4445                           1                    43
# 5403                          69                    43
# 767                            1                    43
# 3480                          69                    43
# 125                           78                    29
# 2955                          95                    29
# 2662                          95                    29
# 3149                          78                    29
# 1834                          71                    29
# 4413                          42                    29
# 5431                          71                    29
# 5555                          42                    29
# 6064                         668                    29
# 6681                          61                    29
# 7669                         482                    34
# 7839                         396                    34
# 303                           38                    29
# 7126                          77                    29
# 6811                          38                    29
# 8003                          77                    29

# %%
# The specific key that correctly identifies a unique flight operation
specific_flight_key = [
    'flight_number',
    'scheduled_departure_datetime_local', # This includes the time
    'scheduled_departure_station_code'
]

# Keep a copy of the original row count to see the change
original_row_count = len(flight_df)

# Drop duplicates based on the specific key, keeping the first instance
flight_df_cleaned = flight_df.drop_duplicates(subset=specific_flight_key, keep='first')

# Get the new row count
cleaned_row_count = len(flight_df_cleaned)

# --- Verification ---
# Re-run the check to confirm there are no duplicates left
remaining_duplicates = flight_df_cleaned.duplicated(subset=specific_flight_key).sum()

print(f"Original row count: {original_row_count}")
print(f"Cleaned row count: {cleaned_row_count}")
print(f"Rows removed: {original_row_count - cleaned_row_count}")
print("-" * 40)
print(f"Remaining duplicates after cleaning: {remaining_duplicates}")

if remaining_duplicates == 0:
    print("✅ Success! The data is now clean, with a unique entry for each flight.")
# Out:
# Original row count: 8099
# Cleaned row count: 8076
# Rows removed: 23
# ----------------------------------------
# Remaining duplicates after cleaning: 0
# ✅ Success! The data is now clean, with a unique entry for each flight.

# %%
flight_key = [
    'flight_number',
    'scheduled_departure_datetime_local', # This includes the time
    'scheduled_departure_station_code'
]

# Now, check for duplicates based on this key
duplicate_rows = flight_df_cleaned.duplicated(subset=flight_key).sum()

# Print the result
print(f"Number of duplicate flights found using the key: {duplicate_rows}")

if duplicate_rows == 0:
    print("✅ The key is unique. Your logic is solid.")
else:
    print("❌ Warning: Duplicate rows found. This indicates a potential data quality issue.")

# Use keep=False to show ALL rows that are part of a duplicate set
duplicate_flights = flight_df_cleaned[flight_df_cleaned.duplicated(subset=flight_key, keep=False)]

# Sort the results to see the duplicates grouped together
print(duplicate_flights.sort_values(by=flight_key))
# Out:
# Number of duplicate flights found using the key: 0
# ✅ The key is unique. Your logic is solid.
# Empty DataFrame
# Columns: [company_id, flight_number, scheduled_departure_date_local, scheduled_departure_station_code, scheduled_arrival_station_code, scheduled_departure_datetime_local, scheduled_arrival_datetime_local, actual_departure_datetime_local, actual_arrival_datetime_local, total_seats, fleet_type, carrier, scheduled_ground_time_minutes, actual_ground_time_minutes, minimum_turn_minutes]
# Index: []

# %%
# --- 3. Aggregate Data to Flight Level ---

# The specific key we will use for the final aggregation
flight_key = [
    'flight_number',
    'scheduled_departure_datetime_local',
    'scheduled_departure_station_code'
]

# The common key for the initial merge (using date only)
merge_key_date_only = [
    'flight_number',
    'scheduled_departure_date_local',
    'scheduled_departure_station_code'
]

# --- Corrected Passenger Aggregation ---

# Define the columns we need from the flight data: the merge key AND the specific time
columns_to_merge = [
    'flight_number',
    'scheduled_departure_date_local',
    'scheduled_departure_station_code',
    'scheduled_departure_datetime_local' # We need both date and datetime
]

# 1. MERGE FIRST to get the exact scheduled time for each passenger
pnr_data_with_datetime = pd.merge(
    pnr_flight_df,
    flight_df_cleaned[columns_to_merge], # Use the corrected list of columns
    on=merge_key_date_only,
    how='left'
)

# 2. AGGREGATE SECOND using the new combined table and the specific key
passenger_agg_df = pnr_data_with_datetime.groupby(flight_key).agg(
    total_passengers=('total_pax', 'sum'),
    child_count=('is_child_numeric', 'sum'),
    stroller_user_count=('is_stroller_user_numeric', 'sum'),
    lap_child_count=('lap_child_count', 'sum'),
    basic_economy_passengers=('basic_economy_ind', 'sum')
).reset_index()

print("✅ Passenger aggregation successful!")
print(passenger_agg_df.head())


print("\nAggregating baggage data...")
# --- Corrected Baggage Aggregation ---

# 1. MERGE FIRST to get the exact scheduled time for each bag record
bag_data_with_datetime = pd.merge(
    bag_df,
    flight_df_cleaned[columns_to_merge], # Using the same columns_to_merge from before
    on=merge_key_date_only,
    how='left'
)

# 2. AGGREGATE SECOND using the new combined table and the specific key
bag_agg_df = bag_data_with_datetime.groupby(flight_key)['bag_type'].value_counts().unstack(fill_value=0).reset_index()

# Clean up column names to be more script-friendly
bag_agg_df.columns = [col.lower().replace(' ', '_').replace('(', '').replace(')', '') for col in bag_agg_df.columns]

print("✅ Baggage aggregation successful!")
print(bag_agg_df.head())


# --- Corrected SSR Aggregation ---

# The specific key we will use for the final aggregation
# specific_flight_key = [
#     'flight_number',
#     'scheduled_departure_datetime_local',
#     'scheduled_departure_station_code'
# ]

# Create a unique list of columns needed for the link table
# This is the PNR identifier + the specific flight key
link_table_columns = [
    'record_locator',
    'pnr_creation_date',
    'flight_number',
    'scheduled_departure_datetime_local',
    'scheduled_departure_station_code'
]

# Create the link table from the enriched PNR data, ensuring unique columns
pnr_link_table = pnr_data_with_datetime[link_table_columns].drop_duplicates()

print("Link table created:")
print(pnr_link_table.head())

# 1. MERGE FIRST: Link SSRs to the enriched PNR data to get the specific flight key
merge_on_keys_ssr = ['record_locator', 'pnr_creation_date', 'flight_number']
remarks_with_keys = pd.merge(
    pnr_remark_df,
    pnr_link_table,
    on=merge_on_keys_ssr,
    how='left'
)
print("✅ SSR merge successful!")
print(remarks_with_keys.head())

# 2. AGGREGATE SECOND: Now group by the specific flight key and count
# Drop rows where the merge couldn't find a flight key, just in case
remarks_with_keys.dropna(subset=flight_key, inplace=True)
ssr_agg_df = remarks_with_keys.groupby(flight_key).size().reset_index(name='ssr_count')


print("✅ SSR aggregation successful!")
print(ssr_agg_df.head())
# Out:
# ✅ Passenger aggregation successful!
#    flight_number scheduled_departure_datetime_local  \
# 0              3          2025-08-01 15:55:00+00:00
# 1              3          2025-08-02 15:55:00+00:00
# 2              3          2025-08-03 15:55:00+00:00
# 3              3          2025-08-04 15:55:00+00:00
# 4              3          2025-08-05 15:55:00+00:00
#
#   scheduled_departure_station_code  total_passengers  child_count  \
# 0                              ORD               177           11
# 1                              ORD               183            8
# 2                              ORD               199           11
# 3                              ORD               199           11
# 4                              ORD               180           10
#
#    stroller_user_count  lap_child_count  basic_economy_passengers
# 0                    0                0                         0
# 1                    1                0                         0
# 2                    3                1                         0
# 3                    3                1                         0
# 4                    2                1                         0
#
# Aggregating baggage data...
# ✅ Baggage aggregation successful!
#    flight_number scheduled_departure_datetime_local  \
# 0              3          2025-08-01 15:55:00+00:00
# 1              3          2025-08-02 15:55:00+00:00
# 2              3          2025-08-03 15:55:00+00:00
# 3              3          2025-08-04 15:55:00+00:00
# 4              3          2025-08-05 15:55:00+00:00
#
#   scheduled_departure_station_code  hot_transfer  origin  transfer
# 0                              ORD             6      70        90
# 1                              ORD            10      80       107
# 2                              ORD             7      82        81
# 3                              ORD             8      58        81
# 4                              ORD            13      74        88
# Link table created:
#   record_locator pnr_creation_date  flight_number  \
# 0     PNR_520583        2025-07-07           2494
# 1     PNR_296107        2025-03-28           2483
# 2     PNR_296108        2025-06-30           1620
# 6     PNR_598394        2025-07-29           5230
# 7     PNR_598394        2025-07-29           2154
#
#   scheduled_departure_datetime_local scheduled_departure_station_code
# 0          2025-08-04 19:53:00+00:00                              ORD
# 1          2025-08-06 10:35:00+00:00                              ORD
# 2          2025-08-01 08:50:00+00:00                              ORD
# 6          2025-08-03 14:00:00+00:00                              ORD
# 7          2025-08-08 18:25:00+00:00                              ORD
# ✅ SSR merge successful!
#   record_locator pnr_creation_date  flight_number special_service_request  \
# 0     PNR_153489        2025-07-04            308      Airport Wheelchair
# 1     PNR_153489        2025-07-04           2182      Airport Wheelchair
# 2     PNR_153508        2025-07-10           2649      Airport Wheelchair
# 3     PNR_153508        2025-07-10           2100      Airport Wheelchair
# 4     PNR_153521        2025-03-01            970     Unaccompanied Minor
#
#   scheduled_departure_datetime_local scheduled_departure_station_code
# 0                                NaT                              NaN
# 1          2025-08-04 11:20:00+00:00                              ORD
# 2          2025-08-08 14:27:00+00:00                              ORD
# 3                                NaT                              NaN
# 4          2025-08-10 15:50:00+00:00                              ORD
# ✅ SSR aggregation successful!
#    flight_number scheduled_departure_datetime_local  \
# 0              3          2025-08-01 15:55:00+00:00
# 1              3          2025-08-02 15:55:00+00:00
# 2              3          2025-08-03 15:55:00+00:00
# 3              3          2025-08-04 15:55:00+00:00
# 4              3          2025-08-05 15:55:00+00:00
#
#   scheduled_departure_station_code  ssr_count
# 0                              ORD          2
# 1                              ORD          1
# 2                              ORD          3
# 3                              ORD          3
# 4                              ORD          4

# %%
# Start with your clean flight data as the base
final_df = flight_df_cleaned.copy()
flight_key = [
    'flight_number',
    'scheduled_departure_datetime_local',
    'scheduled_departure_station_code'
]

# 1. Merge with passenger data
final_df = pd.merge(
    final_df,
    passenger_agg_df,
    on=flight_key,
    how='left'
)

# 2. Merge with baggage data
final_df = pd.merge(
    final_df,
    bag_agg_df,
    on=flight_key,
    how='left'
)

# 3. Merge with SSR data
final_df = pd.merge(
    final_df,
    ssr_agg_df,
    on=flight_key,
    how='left'
)

final_df.info()

# --- Check for and handle duplicate rows after merging ---
print("\n--- Checking for duplicate rows ---")
# It's good practice to check for duplicates after merges.
duplicate_count = final_df.duplicated(subset=flight_key).sum()
print(f"Found {duplicate_count} duplicate rows based on the flight key.")

if duplicate_count > 0:
    # To inspect, you can view all occurrences of duplicated rows
    print("Displaying all occurrences of duplicate rows for inspection:")
    duplicates = final_df[final_df.duplicated(subset=flight_key, keep=False)]
    print(duplicates)
    
    # Remove duplicate rows, keeping the first instance
    final_df.drop_duplicates(subset=flight_key, keep='first', inplace=True)
    print(f"\nRemoved {duplicate_count} duplicate rows. New shape: {final_df.shape}")
print("-" * 50)

# 4. Clean up missing values from the merge
# A flight with no SSRs will have NaN in 'ssr_count'. This should be 0.
# We'll apply this to all new count columns just in case.
count_columns_to_fill = [
    'total_passengers', 'child_count', 'stroller_user_count',
    'lap_child_count', 'basic_economy_passengers',
    'hot_transfer', 'origin', 'transfer',  # From bag_agg_df
    'ssr_count'
]
##check duplicate values here 
final_df.isnull().sum()

# Use a loop to fill NaNs with 0 for all count columns
for col in count_columns_to_fill:
    if col in final_df.columns:
        final_df[col] = final_df[col].fillna(0)


# --- Display your final, unified DataFrame ---
print("✅ Merge complete! Your final analysis-ready dataset is ready.")
print("-" * 50)
print(final_df.info())
print(final_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8076 entries, 0 to 8075
# Data columns (total 24 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   company_id                          8076 non-null   object
#  1   flight_number                       8076 non-null   int64
#  2   scheduled_departure_date_local      8076 non-null   datetime64[ns]
#  3   scheduled_departure_station_code    8076 non-null   object
#  4   scheduled_arrival_station_code      8076 non-null   object
#  5   scheduled_departure_datetime_local  8076 non-null   datetime64[ns, UTC]
#  6   scheduled_arrival_datetime_local    8076 non-null   datetime64[ns, UTC]
#  7   actual_departure_datetime_local     8076 non-null   datetime64[ns, UTC]
#  8   actual_arrival_datetime_local       8076 non-null   datetime64[ns, UTC]
#  9   total_seats                         8076 non-null   int64
#  10  fleet_type                          8076 non-null   object
#  11  carrier                             8076 non-null   object
#  12  scheduled_ground_time_minutes       8076 non-null   int64
#  13  actual_ground_time_minutes          8076 non-null   int64
#  14  minimum_turn_minutes                8076 non-null   int64
#  15  total_passengers                    8076 non-null   int64
#  16  child_count                         8076 non-null   int64
#  17  stroller_user_count                 8076 non-null   int64
#  18  lap_child_count                     8076 non-null   int64
#  19  basic_economy_passengers            8076 non-null   int64
#  20  hot_transfer                        8076 non-null   int64
#  21  origin                              8076 non-null   int64
#  22  transfer                            8076 non-null   int64
#  23  ssr_count                           6246 non-null   float64
# dtypes: datetime64[ns, UTC](4), datetime64[ns](1), float64(1), int64(13), object(5)
# memory usage: 1.5+ MB
#
# --- Checking for duplicate rows ---
# Found 0 duplicate rows based on the flight key.
# --------------------------------------------------
# ✅ Merge complete! Your final analysis-ready dataset is ready.
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8076 entries, 0 to 8075
# Data columns (total 24 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   company_id                          8076 non-null   object
#  1   flight_number                       8076 non-null   int64
#  2   scheduled_departure_date_local      8076 non-null   datetime64[ns]
#  3   scheduled_departure_station_code    8076 non-null   object
#  4   scheduled_arrival_station_code      8076 non-null   object
#  5   scheduled_departure_datetime_local  8076 non-null   datetime64[ns, UTC]
#  6   scheduled_arrival_datetime_local    8076 non-null   datetime64[ns, UTC]
#  7   actual_departure_datetime_local     8076 non-null   datetime64[ns, UTC]
#  8   actual_arrival_datetime_local       8076 non-null   datetime64[ns, UTC]
#  9   total_seats                         8076 non-null   int64
#  10  fleet_type                          8076 non-null   object
#  11  carrier                             8076 non-null   object
#  12  scheduled_ground_time_minutes       8076 non-null   int64
#  13  actual_ground_time_minutes          8076 non-null   int64
#  14  minimum_turn_minutes                8076 non-null   int64
#  15  total_passengers                    8076 non-null   int64
#  16  child_count                         8076 non-null   int64
#  17  stroller_user_count                 8076 non-null   int64
#  18  lap_child_count                     8076 non-null   int64
#  19  basic_economy_passengers            8076 non-null   int64
#  20  hot_transfer                        8076 non-null   int64
#  21  origin                              8076 non-null   int64
#  22  transfer                            8076 non-null   int64
#  23  ssr_count                           8076 non-null   float64
# dtypes: datetime64[ns, UTC](4), datetime64[ns](1), float64(1), int64(13), object(5)
# memory usage: 1.5+ MB
# None
#   company_id  flight_number scheduled_departure_date_local  \
# 0         OO           4792                     2025-08-04
# 1         UA            920                     2025-08-03
# 2         UA           1776                     2025-08-10
# 3         OO           5790                     2025-08-06
# 4         UA           1398                     2025-08-05
#
#   scheduled_departure_station_code scheduled_arrival_station_code  \
# 0                              ORD                            ROA
# 1                              ORD                            LHR
# 2                              ORD                            PHL
# 3                              ORD                            CRW
# 4                              ORD                            ATL
#
#   scheduled_departure_datetime_local scheduled_arrival_datetime_local  \
# 0          2025-08-04 17:57:00+00:00        2025-08-04 21:04:00+00:00
# 1          2025-08-03 18:05:00+00:00        2025-08-04 08:20:00+00:00
# 2          2025-08-10 18:20:00+00:00        2025-08-10 21:35:00+00:00
# 3          2025-08-06 18:20:00+00:00        2025-08-06 21:04:00+00:00
# 4          2025-08-05 18:20:00+00:00        2025-08-05 21:29:00+00:00
#
#   actual_departure_datetime_local actual_arrival_datetime_local  total_seats  \
# 0       2025-08-04 18:04:00+00:00     2025-08-04 20:52:00+00:00           76
# 1       2025-08-03 18:27:00+00:00     2025-08-04 08:06:00+00:00          167
# 2       2025-08-10 20:11:00+00:00     2025-08-10 23:26:00+00:00          166
# 3       2025-08-06 20:05:00+00:00     2025-08-06 22:42:00+00:00           50
# 4       2025-08-05 18:16:00+00:00     2025-08-05 21:49:00+00:00          166
#
#    ... minimum_turn_minutes total_passengers  child_count  \
# 0  ...                   34               65            1
# 1  ...                  145              171            5
# 2  ...                   51              180            5
# 3  ...                   29               55            2
# 4  ...                   51              136            3
#
#    stroller_user_count  lap_child_count  basic_economy_passengers  \
# 0                    0                0                         7
# 1                    0                1                         0
# 2                    2                0                        18
# 3                    0                0                         2
# 4                    0                0                        11
#
#    hot_transfer  origin  transfer  ssr_count
# 0            16       6        20        3.0
# 1            16      90        37        3.0
# 2             1      46        38        0.0
# 3             0      14        40        2.0
# 4             0      19        51        2.0
#
# [5 rows x 24 columns]

# %%
# a. Calculate Departure Delay in Minutes
final_df['departure_delay'] = (
    final_df['actual_departure_datetime_local'] - final_df['scheduled_departure_datetime_local']
).dt.total_seconds() / 60

# b. Calculate Passenger Load Factor
final_df['passenger_load_factor'] = final_df['total_passengers'] / final_df['total_seats']
# CORRECTED LINE: Assign the result back to the column
final_df['passenger_load_factor'] = final_df['passenger_load_factor'].fillna(0)
final_df.loc[final_df['total_seats'] == 0, 'passenger_load_factor'] = 0

# c. Calculate Ground Time Pressure
final_df['ground_time_pressure'] = final_df['scheduled_ground_time_minutes'] - final_df['minimum_turn_minutes']

# d. Calculate Transfer Bag Ratio
total_bags = final_df['origin'] + final_df['transfer'] + final_df['hot_transfer']
final_df['transfer_bag_ratio'] = final_df['transfer'] / total_bags
# CORRECTED LINE: Assign the result back to the column
final_df['transfer_bag_ratio'] = final_df['transfer_bag_ratio'].fillna(0)

print("New features engineered successfully!")
print(final_df[['departure_delay', 'passenger_load_factor', 'ground_time_pressure', 'transfer_bag_ratio']].head())
# Out:
# New features engineered successfully!
#    departure_delay  passenger_load_factor  ground_time_pressure  \
# 0              7.0               0.855263                     8
# 1             22.0               1.023952                    90
# 2            111.0               1.084337                    25
# 3            105.0               1.100000                   194
# 4             -4.0               0.819277                    24
#
#    transfer_bag_ratio
# 0            0.476190
# 1            0.258741
# 2            0.447059
# 3            0.740741
# 4            0.728571

# %%
avg_delay = final_df['departure_delay'].mean()
late_flights_percentage = (final_df['departure_delay'] > 0).mean() * 100

print(f"Average departure delay: {avg_delay:.2f} minutes")
print(f"Percentage of flights departing late: {late_flights_percentage:.2f}%")
# Out:
# Average departure delay: 21.19 minutes
# Percentage of flights departing late: 49.65%

# %%
tight_ground_time_flights = (final_df['ground_time_pressure'] < 0).sum()

print(f"Number of flights with scheduled ground time below minimum: {tight_ground_time_flights}")
# Out:
# Number of flights with scheduled ground time below minimum: 621

# %%
# Create a temporary column for the ratio, handling cases with 0 checked bags
temp_df = final_df[final_df['origin'] > 0].copy() # Avoid division by zero
temp_df['transfer_vs_checked_ratio'] = temp_df['transfer'] / temp_df['origin']
avg_transfer_ratio = temp_df['transfer_vs_checked_ratio'].mean()

print(f"Average ratio of transfer bags to checked bags: {avg_transfer_ratio:.2f}")
# Out:
# Average ratio of transfer bags to checked bags: 3.05

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate correlation
correlation = final_df['passenger_load_factor'].corr(final_df['departure_delay'])
print(f"Correlation between Passenger Load Factor and Departure Delay: {correlation:.2f}")

# Create scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=final_df, x='passenger_load_factor', y='departure_delay')
plt.title('Passenger Load Factor vs. Departure Delay')
plt.xlabel('Passenger Load Factor')
plt.ylabel('Departure Delay (minutes)')
plt.grid(True)
plt.show()
# Out:
# Correlation between Passenger Load Factor and Departure Delay: -0.15

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# --- Analysis: Are high SSR flights also high-delay after controlling for load? ---

print("--- Answering: Are high SSR flights also high-delay after controlling for load? ---")

# 1. Create Passenger Load Bins
# We'll use pd.cut to segment flights into clear load categories.
# Let's define bins for: < 80% full, 80-95% full, and > 95% full.
load_bins = [0, 0.80, 0.95, 1.01] # Use 1.01 to include flights that are 100% full
load_labels = ['Medium Load (<80%)', 'High Load (80-95%)', 'Very High Load (>95%)']
final_df['load_category'] = pd.cut(final_df['passenger_load_factor'], bins=load_bins, labels=load_labels, right=False)

# 2. Create SSR Bins
# We can use quantiles to define "low" vs "high" SSR counts dynamically.
# Let's define 'Low' as below the median and 'High' as above the median.
ssr_median = final_df['ssr_count'].median()
final_df['ssr_category'] = np.where(final_df['ssr_count'] > ssr_median, 'High SSR', 'Low SSR')

# 3. Group by both categories and calculate the average delay
# This is the core of "controlling for load". We calculate the mean delay for each sub-group.
controlled_analysis = final_df.groupby(['load_category', 'ssr_category'],observed=True)['departure_delay'].mean().reset_index()

print("\nAverage Delay (in mins) by SSR Count, Controlled for Passenger Load:")
# Pivot for better readability
controlled_pivot = controlled_analysis.pivot(index='load_category', columns='ssr_category', values='departure_delay')
print(controlled_pivot)


# 4. Visualize the results for a clear presentation
plt.figure(figsize=(12, 7))
sns.barplot(
    data=controlled_analysis,
    x='load_category',
    y='departure_delay',
    hue='ssr_category',
    palette={'Low SSR': 'skyblue', 'High SSR': 'navy'}
)

plt.title('Impact of SSRs on Delay, Controlled for Passenger Load', fontsize=16)
plt.xlabel('Passenger Load Category', fontsize=12)
plt.ylabel('Average Departure Delay (minutes)', fontsize=12)
plt.legend(title='SSR Level')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# --- Answering: Are high SSR flights also high-delay after controlling for load? ---
#
# Average Delay (in mins) by SSR Count, Controlled for Passenger Load:
# ssr_category            High SSR    Low SSR
# load_category
# Medium Load (<80%)     53.418301  44.464807
# High Load (80-95%)     35.996835  21.840979
# Very High Load (>95%)  21.564394  14.721332

# %%
# The Key Insight: In every single load category, flights with a "High SSR" count have a significantly higher average departure delay than flights with a "Low SSR" count.

# This is a powerful finding. It proves that SSRs are an independent driver of operational difficulty. It's not just that full flights have more SSRs and more delays; even when comparing two equally full flights, the one with more special service requests is substantially more likely to be delayed.

# This directly justifies giving ssr_count a meaningful weight in your Flight Difficulty Score.

# # A Surprising Secondary Insight: Notice that as the passenger_load_factor increases, the overall average delay decreases. This is counter-intuitive but very valuable. It might suggest that the airline dedicates more experienced crews or has more streamlined processes for its fullest (and likely most profitable) flights. This is a fantastic point to mention in your presentation as an area for further study.

# %%
# Cap the passenger_load_factor at a maximum of 1.0
final_df['passenger_load_factor'] = final_df['passenger_load_factor'].clip(upper=1.0)
print("Passenger load factor cleaned.")
# Out:
# Passenger load factor cleaned.

# %%
from sklearn.preprocessing import MinMaxScaler

# --- Step 1: Select the features that will go into our score ---
# Based on your EDA, these are strong candidates for "difficulty"
features_for_score = [
    'ground_time_pressure',
    'passenger_load_factor',
    'transfer_bag_ratio',
    'ssr_count',
    'hot_transfer', # Number of time-sensitive transfer bags
    'child_count',
    'lap_child_count'
]

# Create a new DataFrame with just these features
score_features = final_df[features_for_score].copy()

# --- Step 2: Normalize the features ---
# We scale all features to a 0-1 range so they can be compared and combined.
# NOTE: For ground_time_pressure, lower is harder, so we'll flip it by multiplying by -1.
score_features['ground_time_pressure'] = score_features['ground_time_pressure'] * -1

scaler = MinMaxScaler()
score_features_scaled = pd.DataFrame(scaler.fit_transform(score_features), columns=score_features.columns)

# --- Step 3: Assign Weights and Calculate the Score ---
# This is where you use your insights! Weights should sum to 1.0.
# We give higher weights to factors we think are more important (like ground time).
weights = {
    'ground_time_pressure': 0.30,
    'passenger_load_factor': 0.15,
    'transfer_bag_ratio': 0.20,
    'ssr_count': 0.15,
    'hot_transfer': 0.10,
    'child_count': 0.05,
    'lap_child_count': 0.05
}

# Calculate the weighted score
final_df['difficulty_score'] = (
    score_features_scaled['ground_time_pressure'] * weights['ground_time_pressure'] +
    score_features_scaled['passenger_load_factor'] * weights['passenger_load_factor'] +
    score_features_scaled['transfer_bag_ratio'] * weights['transfer_bag_ratio'] +
    score_features_scaled['ssr_count'] * weights['ssr_count'] +
    score_features_scaled['hot_transfer'] * weights['hot_transfer'] +
    score_features_scaled['child_count'] * weights['child_count'] +
    score_features_scaled['lap_child_count'] * weights['lap_child_count']
)

# --- Step 4: Create Daily Rank and Classification ---
# This meets the deliverable requirements.

# a. Daily Rank (higher rank = more difficult)
final_df['daily_difficulty_rank'] = final_df.groupby(
    final_df['scheduled_departure_datetime_local'].dt.date
)['difficulty_score'].rank(method='dense', ascending=False)

# b. Classification into 3 Tiers
# We use quantiles (e.g., top 20%, middle 50%, bottom 30%) for classification
final_df['difficulty_class'] = pd.qcut(
    final_df['daily_difficulty_rank'],
    q=[0, 0.3, 0.8, 1.0],
    labels=['Difficult', 'Medium', 'Easy']
)


print("\n✅ Flight Difficulty Score, Rank, and Class created successfully!")
# Display the final results
print(final_df[[
    'flight_number', 'scheduled_departure_datetime_local', 'difficulty_score',
    'daily_difficulty_rank', 'difficulty_class'
]].sort_values(by='difficulty_score', ascending=False).head(10))
# Out:
# ✅ Flight Difficulty Score, Rank, and Class created successfully!
#       flight_number scheduled_departure_datetime_local  difficulty_score  \
# 3315            972          2025-08-11 17:55:00+00:00          0.748030
# 4869            972          2025-08-05 17:55:00+00:00          0.734178
# 4004            845          2025-08-07 21:20:00+00:00          0.729050
# 3035            845          2025-08-04 21:20:00+00:00          0.712098
# 6997            845          2025-08-06 21:20:00+00:00          0.709956
# 3265            972          2025-08-13 17:55:00+00:00          0.708843
# 7250            845          2025-08-11 21:20:00+00:00          0.705082
# 1448           1616          2025-08-02 18:32:00+00:00          0.693745
# 4636            845          2025-08-08 21:20:00+00:00          0.693643
# 6641           2113          2025-08-09 20:08:00+00:00          0.692928
#
#       daily_difficulty_rank difficulty_class
# 3315                    1.0        Difficult
# 4869                    1.0        Difficult
# 4004                    1.0        Difficult
# 3035                    1.0        Difficult
# 6997                    1.0        Difficult
# 3265                    1.0        Difficult
# 7250                    2.0        Difficult
# 1448                    1.0        Difficult
# 4636                    1.0        Difficult
# 6641                    1.0        Difficult

# %%
difficult_flights = final_df[final_df['difficulty_class'] == 'Difficult']

print("--- Top 10 Most Difficult Destinations ---")
print(difficult_flights['scheduled_arrival_station_code'].value_counts().head(10))
# Out:
# --- Top 10 Most Difficult Destinations ---
# scheduled_arrival_station_code
# STL    88
# DTW    54
# GRR    53
# DSM    53
# MSP    51
# DAY    51
# CLE    49
# CID    49
# OMA    48
# SEA    45
# Name: count, dtype: int64

# %%
# Assume 'final_df' is your main DataFrame and 'difficult_flights' is the filtered one.
# final_df = ...
# difficult_flights = final_df[final_df['difficulty_class'] == 'Difficult']

# --- Analysis: Find the Common Drivers for a Specific Difficult Destination ---

# 1. Define the destination for our deep dive (e.g., 'STL', the top difficult destination)
destination_of_interest = 'STL'

# 2. Isolate the specific group to analyze: Difficult flights to STL
stl_difficult_flights = difficult_flights[difficult_flights['scheduled_arrival_station_code'] == destination_of_interest]

# 3. Define the key features we want to investigate as potential drivers
features_to_compare = [
    'departure_delay',
    'ground_time_pressure',
    'transfer_bag_ratio',
    'ssr_count',
    'passenger_load_factor'
]

# 4. Calculate the average values for our specific group (Difficult STL flights)
group_averages = stl_difficult_flights[features_to_compare].mean()

# 5. Calculate the average values for ALL flights to establish a baseline
overall_averages = final_df[features_to_compare].mean()

# 6. Create a comparison DataFrame to see the numbers side-by-side
comparison_df = pd.DataFrame({
    f'{destination_of_interest}_Difficult_Avg': group_averages,
    'Overall_Airport_Avg': overall_averages
})

# 7. Calculate the percentage difference to quantify the gap
comparison_df['pct_difference'] = (
    (comparison_df[f'{destination_of_interest}_Difficult_Avg'] - comparison_df['Overall_Airport_Avg']) /
     comparison_df['Overall_Airport_Avg']
) * 100

# --- Display the Results ---
print(f"--- Analysis of Common Drivers for Difficult Flights to {destination_of_interest} ---")
print(comparison_df)
# Out:
# --- Analysis of Common Drivers for Difficult Flights to STL ---
#                        STL_Difficult_Avg  Overall_Airport_Avg  pct_difference
# departure_delay                23.681818            21.190441       11.757081
# ground_time_pressure           80.693182           135.977464      -40.656945
# transfer_bag_ratio              0.828204             0.515645       60.615179
# ssr_count                       1.727273             2.116890      -18.405156
# passenger_load_factor           0.990201             0.934599        5.949296

# %%
# Of course. This is the most critical part of the project—translating your analytical findings into a concrete, actionable strategy for United Airlines. Based on your analysis, particularly the deep dive into the St. Louis (STL) route, we can formulate very specific recommendations.

# The core finding is that difficulty is not random; it's driven by identifiable factors. Therefore, the solution is not to add resources everywhere, but to apply them surgically where the data shows they are needed most.

# Here are three specific, data-driven recommendations for better operational efficiency:

# Recommendation 1: Create a "Proactive Operations Team" for High-Pressure Turnarounds
# The Finding: The single biggest driver of difficulty is ground_time_pressure. Difficult flights to STL have 51% less ground time buffer than average, meaning they are operationally compromised before they even land.

# The Specific Action: Instead of reacting to delays, proactively intervene. Each morning, use the Flight Difficulty Score to identify the Top 5 flights ranked as 'Difficult' due to severe ground time pressure. Assign a dedicated "Proactive Operations Team" (e.g., an extra ramp lead and a dedicated ground operations coordinator) to these specific flights. Their mission is to ensure all pre-departure tasks (fueling, catering, cleaning) are completed 15 minutes ahead of the standard schedule, creating a buffer where none exists.

# Business Justification: This is a targeted, high-ROI use of resources. Instead of overstaffing the entire airport, you apply focused expertise to the 5-10 flights most likely to cause cascading delays, directly mitigating the #1 risk factor.

# Recommendation 2: Implement a "Priority Transfer Bag" Protocol for Complex Flights
# The Finding: The second-largest driver is baggage complexity. Difficult flights to STL handle 50% more transfer bags than the average flight, straining baggage handling systems.

# The Specific Action: For flights flagged by the score as 'Difficult' due to a high transfer_bag_ratio, implement a "Priority Transfer" protocol. When the inbound connecting flights arrive, baggage handlers are instructed via their scanners to unload and transport the bags destined for these priority flights first. This ensures the most complex part of the baggage operation is handled with the most urgency.

# Business Justification: This directly reduces the risk of holding a flight for late-arriving bags, a common cause of departure delays. It streamlines the most chaotic part of the ground operation and reduces the likelihood of mishandled or lost baggage, improving customer satisfaction.

# Recommendation 3: Launch a Pilot Program Focused on the STL Route
# The Finding: The St. Louis (STL) route is consistently the most difficult, making it the perfect test case for these new strategies.

# The Specific Action: Roll out Recommendations 1 and 2 as a one-month pilot program focused exclusively on flights to St. Louis. During this period, track two key metrics for STL flights:

# On-Time Performance (OTP): Measure the percentage of flights that depart on time.
# Average Departure Delay: Measure the average delay in minutes.
# Compare these metrics against the baseline you established in your analysis.

# Business Justification: A pilot program is a low-risk, high-reward way to prove the value of your data-driven approach. A successful outcome (e.g., a 10% improvement in OTP for STL flights) provides a powerful, quantifiable business case to expand these strategies to the next most difficult routes (like DEN, LAX, etc.) identified by your model.

# By implementing these recommendations, United Airlines can shift from a reactive, "firefighting" operational model to a proactive, data-informed one, leading to better on-time performance, more efficient resource use, and a less stressful environment for frontline teams.

# %%
# Select columns for the final CSV output
output_columns = ['flight_number', 'scheduled_departure_datetime_local', 'scheduled_arrival_station_code'] \
                 + features_for_score \
                 + ['difficulty_score', 'daily_difficulty_rank', 'difficulty_class']

final_output_df = final_df[output_columns]
final_output_df.to_csv('test_yourname.csv', index=False)

# %%
import pandas as pd

# Assume 'final_df' is your fully prepared DataFrame from the previous steps
# and 'features_for_score' is the list of feature names you used.

# --- 1. Post-Analysis: Identify Difficult Destinations and Drivers ---

print("---" * 20)
print("POST-ANALYSIS & INSIGHTS")
print("---" * 20)

# a. Find the top 10 most consistently difficult destinations
difficult_flights = final_df[final_df['difficulty_class'] == 'Difficult']
top_difficult_destinations = difficult_flights['scheduled_arrival_station_code'].value_counts().head(10)

print("\n--- Top 10 Most Difficult Destinations ---")
print(top_difficult_destinations)

# b. Analyze the drivers for the #1 most difficult destination
if not top_difficult_destinations.empty:
    top_destination_code = top_difficult_destinations.index[0]
    
    # Filter for all flights to that top destination
    top_dest_flights = final_df[final_df['scheduled_arrival_station_code'] == top_destination_code]

    # Calculate the average metrics for those flights
    top_dest_metrics = top_dest_flights[features_for_score + ['departure_delay']].mean()
    
    # Calculate the airport-wide average for comparison
    airport_wide_metrics = final_df[features_for_score + ['departure_delay']].mean()
    
    # Combine them into a single DataFrame for easy comparison
    comparison_df = pd.DataFrame({
        f'Avg. for {top_destination_code}': top_dest_metrics,
        'Airport-Wide Avg.': airport_wide_metrics
    })
    comparison_df['Difference (%)'] = (comparison_df[f'Avg. for {top_destination_code}'] - comparison_df['Airport-Wide Avg.']) / comparison_df['Airport-Wide Avg.'] * 100

    print(f"\n--- Analysis of Drivers for Top Destination: {top_destination_code} ---")
    print(comparison_df.round(2))
else:
    print("\nNo 'Difficult' flights found to analyze.")

# --- 2. Final Deliverable: Create the Submission CSV File ---

print("\n" + "---" * 20)
print("GENERATING FINAL SUBMISSION CSV")
print("---" * 20)

# Define the columns required for the final output file
output_columns = [
    'flight_number', 
    'scheduled_departure_datetime_local', 
    'scheduled_arrival_station_code'
] + features_for_score + [
    'difficulty_score', 
    'daily_difficulty_rank', 
    'difficulty_class'
]

# Create the final DataFrame with the specified columns
final_output_df = final_df[output_columns]

# Define the filename (remember to replace 'yourname')
output_filename = 'test_yourname1.csv'

# Save the DataFrame to a CSV file
try:
    final_output_df.to_csv(output_filename, index=False)
    print(f"\n✅ Successfully saved the final output to '{output_filename}'")
    print(f"Total rows in CSV: {len(final_output_df)}")
except Exception as e:
    print(f"\n❌ Error saving file: {e}")

# Display the head of the file you just created to double-check
print("\n--- First 5 rows of the output CSV file ---")
print(final_output_df.head())
